# %%
from ML_based_classification import find_best_paper
import json
import pandas as pd
import numpy as np
# Out:
# Loading 20 papers...
# 2025-11-19 23:48:34,365 - INFO - Connected to Milvus Lite: ./milvus_final.db
# 2025-11-19 23:48:34,425 - INFO - PyTorch version 2.9.1 available.
# 2025-11-19 23:48:34,719 - INFO - Load pretrained SparseEncoder: opensearch-project/opensearch-neural-sparse-encoding-doc-v2-distill
# 2025-11-19 23:48:37,498 - INFO - Loaded SPLADE model: opensearch-project/opensearch-neural-sparse-encoding-doc-v2-distill
# Database file found.
# Index is already populated. SKIPPING ingestion.

# %%
# load test queries
with open("queries.json", "r", encoding="utf-8") as f:
    test_queries = json.load(f)

print(len(test_queries), "test queries loaded.")
# Out:
# 20 test queries loaded.

# %%
results = []

# test RAG model on the queries
for entry in test_queries:
    question = entry['question']
    correct_paper = str(entry['correct_paper']) # id of the correct paper
    
    predicted_paper = find_best_paper(question)
    
    is_correct = predicted_paper == correct_paper # True if the prediction matches the correct paper
    
    results.append({
        "question": question,
        "predicted_paper": predicted_paper,
        "correct_paper": correct_paper,
        "is_correct": is_correct
    })
# Out:
# Querying: 'How are Transformers different from RNNs?'
# Batches: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 1.7632 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
# Rank 2: Score 1.4678 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
# Rank 3: Score 1.2358 | Paper: 2510.12850v1 [Ethic-BERT: An Enhan...] | Text: Ethic-BERT: An Enhanced Deep Learning Mo...
# Rank 4: Score 0.7834 | Paper: 2510.13937v1 [Rock Classification ...] | Text: Rock Classification through Knowledge-En...
# Rank 5: Score 0.6503 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
#
# --- Classification Result ---
# Predicted Paper: 2510.09187v1
# Total Similarity Score: 1.7632
# Querying: 'What are the advantages and drawbacks of batch normalization compared to layer normalization?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.92it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 2.4848 | Paper: 2510.08116v1 [Random Window Augmen...] | Text: Random Window Augmentations for Deep Lea...
# Rank 2: Score 2.1627 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 3: Score 2.1067 | Paper: 2510.08770v1 [Detecting spills usi...] | Text: Detecting spills using thermal imaging, ...
# Rank 4: Score 2.0997 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 5: Score 1.6420 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
#
# --- Classification Result ---
# Predicted Paper: 2510.08116v1
# Total Similarity Score: 2.4848
# Querying: 'What regularization techniques help reduce overfitting in large language models?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.17it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 7.7578 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 2: Score 6.6755 | Paper: 2510.08116v1 [Random Window Augmen...] | Text: Random Window Augmentations for Deep Lea...
# Rank 3: Score 6.4963 | Paper: 2509.23158v1 [Deep Learning-Based ...] | Text: Deep Learning-Based Detection of Cogniti...
# Rank 4: Score 5.7589 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 5: Score 5.7529 | Paper: 2510.10729v1 [Sarcasm Detection Us...] | Text: Sarcasm is a nuanced and often misinterp...
#
# --- Classification Result ---
# Predicted Paper: 2510.10822v1
# Total Similarity Score: 7.7578
# Querying: 'Which learning rate schedules are most effective when training deep learning models?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.42it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 12.5332 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 2: Score 11.8185 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 3: Score 10.3345 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
# Rank 4: Score 9.8440 | Paper: 2510.07320v1 [Deep Learning Based ...] | Text: Deep Learning Based Approach to Enhanced...
# Rank 5: Score 9.7551 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
#
# --- Classification Result ---
# Predicted Paper: 2510.10822v1
# Total Similarity Score: 12.5332
# Querying: 'What problems might I encounter when fine-tuning models on domain-specific data?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.94it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 7.6863 | Paper: 2510.12850v1 [Ethic-BERT: An Enhan...] | Text: Ethic-BERT: An Enhanced Deep Learning Mo...
# Rank 2: Score 5.5958 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 3: Score 5.3767 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
# Rank 4: Score 5.3714 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 5: Score 4.5529 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
#
# --- Classification Result ---
# Predicted Paper: 2510.12850v1
# Total Similarity Score: 7.6863
# Querying: 'How can I assess image-text alignment in multimodal models?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.31it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 5.6265 | Paper: 2510.11301v1 [TDADL-IE: A Deep Lea...] | Text: TDADL-IE: A Deep Learning-Driven Cryptog...
# Rank 2: Score 5.4640 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
# Rank 3: Score 5.3024 | Paper: 2510.12850v1 [Ethic-BERT: An Enhan...] | Text: Ethic-BERT: An Enhanced Deep Learning Mo...
# Rank 4: Score 5.1973 | Paper: 2509.23158v1 [Deep Learning-Based ...] | Text: Deep Learning-Based Detection of Cogniti...
# Rank 5: Score 5.0472 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
#
# --- Classification Result ---
# Predicted Paper: 2510.11301v1
# Total Similarity Score: 5.6265
# Querying: 'What metrics should I use to evaluate text generation models?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.64it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 5.3893 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
# Rank 2: Score 5.3577 | Paper: 2510.12850v1 [Ethic-BERT: An Enhan...] | Text: Ethic-BERT: An Enhanced Deep Learning Mo...
# Rank 3: Score 5.2073 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
# Rank 4: Score 5.0361 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 5: Score 4.9410 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
#
# --- Classification Result ---
# Predicted Paper: 2510.08662v1
# Total Similarity Score: 5.3893
# Querying: 'How can we detect sarcasm using deep learning?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.19it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 11.1220 | Paper: 2510.10729v1 [Sarcasm Detection Us...] | Text: Sarcasm is a nuanced and often misinterp...
# Rank 2: Score 10.1309 | Paper: 2509.23158v1 [Deep Learning-Based ...] | Text: Deep Learning-Based Detection of Cogniti...
# Rank 3: Score 8.6633 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 4: Score 8.3862 | Paper: 2510.07320v1 [Deep Learning Based ...] | Text: Deep Learning Based Approach to Enhanced...
# Rank 5: Score 8.3312 | Paper: 2510.08770v1 [Detecting spills usi...] | Text: Detecting spills using thermal imaging, ...
#
# --- Classification Result ---
# Predicted Paper: 2510.10729v1
# Total Similarity Score: 11.1220
# Querying: 'How can I detect or measure bias in deep learning models?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.38it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 14.1613 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 2: Score 11.8220 | Paper: 2509.23158v1 [Deep Learning-Based ...] | Text: Deep Learning-Based Detection of Cogniti...
# Rank 3: Score 11.0224 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 4: Score 9.8861 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
# Rank 5: Score 9.7512 | Paper: 2510.08770v1 [Detecting spills usi...] | Text: Detecting spills using thermal imaging, ...
#
# --- Classification Result ---
# Predicted Paper: 2510.10822v1
# Total Similarity Score: 14.1613
# Querying: 'How can I reduce hallucinations in large language models?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.40it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 4.7013 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 2: Score 3.9741 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
# Rank 3: Score 3.8702 | Paper: 2509.23158v1 [Deep Learning-Based ...] | Text: Deep Learning-Based Detection of Cogniti...
# Rank 4: Score 3.7534 | Paper: 2510.10729v1 [Sarcasm Detection Us...] | Text: Sarcasm is a nuanced and often misinterp...
# Rank 5: Score 3.2031 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
#
# --- Classification Result ---
# Predicted Paper: 2510.10822v1
# Total Similarity Score: 4.7013
# Querying: 'What techniques improve Transformer training speed without losing performance?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.83it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 8.7041 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 2: Score 6.3655 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
# Rank 3: Score 6.3196 | Paper: 2510.08116v1 [Random Window Augmen...] | Text: Random Window Augmentations for Deep Lea...
# Rank 4: Score 5.8520 | Paper: 2509.23158v1 [Deep Learning-Based ...] | Text: Deep Learning-Based Detection of Cogniti...
# Rank 5: Score 5.3562 | Paper: 2510.12850v1 [Ethic-BERT: An Enhan...] | Text: Ethic-BERT: An Enhanced Deep Learning Mo...
#
# --- Classification Result ---
# Predicted Paper: 2510.10822v1
# Total Similarity Score: 8.7041
# Querying: 'Are deep learning methods effective for crime forecasting compared to traditional models?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.15it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 24.5569 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 2: Score 15.5865 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 3: Score 14.4937 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
# Rank 4: Score 13.9657 | Paper: 2510.13050v1 [An Operational Deep ...] | Text: An Operational Deep Learning System for ...
# Rank 5: Score 12.3137 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
#
# --- Classification Result ---
# Predicted Paper: 2509.20913v1
# Total Similarity Score: 24.5569
# Querying: 'Should I train separate models for different crime types, or combine them?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.04it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 10.3884 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 2: Score 6.3468 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
# Rank 3: Score 5.9867 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 4: Score 4.0464 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
# Rank 5: Score 4.0154 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
#
# --- Classification Result ---
# Predicted Paper: 2509.20913v1
# Total Similarity Score: 10.3884
# Querying: 'Which deep learning approaches work well for gamma/hadron separation?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.33it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 14.3035 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
# Rank 2: Score 9.0664 | Paper: 2510.07320v1 [Deep Learning Based ...] | Text: Deep Learning Based Approach to Enhanced...
# Rank 3: Score 9.0596 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 4: Score 8.2442 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 5: Score 7.7623 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
#
# --- Classification Result ---
# Predicted Paper: 2510.05736v1
# Total Similarity Score: 14.3035
# Querying: 'What frameworks and optimization strategies were used to train DPCformer?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.76it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 11.5249 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
# Rank 2: Score 9.8547 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
# Rank 3: Score 9.3497 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 4: Score 7.7451 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 5: Score 7.0355 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
#
# --- Classification Result ---
# Predicted Paper: 2510.08662v1
# Total Similarity Score: 11.5249
# Querying: 'How do modern architectures perform on complex video tasks compared to older methods?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.33it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 7.5820 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
# Rank 2: Score 5.4298 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
# Rank 3: Score 3.8491 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
# Rank 4: Score 3.8468 | Paper: 2510.11301v1 [TDADL-IE: A Deep Lea...] | Text: TDADL-IE: A Deep Learning-Driven Cryptog...
# Rank 5: Score 3.7759 | Paper: 2510.10729v1 [Sarcasm Detection Us...] | Text: Sarcasm is a nuanced and often misinterp...
#
# --- Classification Result ---
# Predicted Paper: 2510.09187v1
# Total Similarity Score: 7.5820
# Querying: 'How can I train models stably with limited computational resources?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.99it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 10.4652 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 2: Score 10.1739 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 3: Score 8.9484 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
# Rank 4: Score 8.8353 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
# Rank 5: Score 8.5559 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
#
# --- Classification Result ---
# Predicted Paper: 2509.20913v1
# Total Similarity Score: 10.4652
# Querying: 'Why is preprocessing important for Ethic-BERT’s performance?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.37it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 7.1062 | Paper: 2510.12850v1 [Ethic-BERT: An Enhan...] | Text: Ethic-BERT: An Enhanced Deep Learning Mo...
# Rank 2: Score 2.9966 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 3: Score 2.9181 | Paper: 2510.10729v1 [Sarcasm Detection Us...] | Text: Sarcasm is a nuanced and often misinterp...
# Rank 4: Score 2.5614 | Paper: 2510.08770v1 [Detecting spills usi...] | Text: Detecting spills using thermal imaging, ...
# Rank 5: Score 2.4339 | Paper: 2510.08116v1 [Random Window Augmen...] | Text: Random Window Augmentations for Deep Lea...
#
# --- Classification Result ---
# Predicted Paper: 2510.12850v1
# Total Similarity Score: 7.1062
# Querying: 'What are the main strengths of using an LSTM model for real-time sign language translation?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.22it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 13.1348 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
# Rank 2: Score 6.5288 | Paper: 2509.20913v1 [Deep Learning for Cr...] | Text: Deep Learning for Crime Forecasting: The...
# Rank 3: Score 5.5554 | Paper: 2510.10729v1 [Sarcasm Detection Us...] | Text: Sarcasm is a nuanced and often misinterp...
# Rank 4: Score 5.5271 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
# Rank 5: Score 5.3693 | Paper: 2510.09187v1 [Modern Deep Learning...] | Text: Modern Deep Learning Approaches for Cric...
#
# --- Classification Result ---
# Predicted Paper: 2510.13137v1
# Total Similarity Score: 13.1348
# Querying: 'How does model selection affect responsiveness in real-time applications?'
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.89it/s]
# --- Top 5 Chunks & Actual Similarity Scores ---
# Rank 1: Score 7.0592 | Paper: 2510.08662v1 [DPCformer: An Interp...] | Text: DPCformer: An Interpretable Deep Learnin...
# Rank 2: Score 6.1272 | Paper: 2510.12850v1 [Ethic-BERT: An Enhan...] | Text: Ethic-BERT: An Enhanced Deep Learning Mo...
# Rank 3: Score 5.5221 | Paper: 2510.10822v1 [From Detection to Mi...] | Text: From Detection to Mitigation Addressing ...
# Rank 4: Score 5.0815 | Paper: 2510.13137v1 [Real-Time Sign Langu...] | Text: Real-Time Sign Language to text Translat...
# Rank 5: Score 4.7048 | Paper: 2510.05736v1 [Convolution and Grap...] | Text: Convolution and Graph-based Deep Learnin...
#
# --- Classification Result ---
# Predicted Paper: 2510.08662v1
# Total Similarity Score: 7.0592

# %%
df_results = pd.DataFrame(results)

# replace "None" strings with actual NaN values
df_results['correct_paper'] = df_results['correct_paper'].replace(to_replace="None", value=np.nan)

# compute accuracy only on rows with a known correct paper
accuracy = df_results[df_results['correct_paper'].notna()]['is_correct'].mean()

valid_queries = df_results['correct_paper'].notna().sum()

print(f"Accuracy over {valid_queries} queries with known correct paper: {accuracy:.2%}")

df_results
# Out:
# Accuracy over 9 queries with known correct paper: 66.67%
#                                              question predicted_paper  \
# 0           How are Transformers different from RNNs?    2510.09187v1
# 1   What are the advantages and drawbacks of batch...    2510.08116v1
# 2   What regularization techniques help reduce ove...    2510.10822v1
# 3   Which learning rate schedules are most effecti...    2510.10822v1
# 4   What problems might I encounter when fine-tuni...    2510.12850v1
# 5   How can I assess image-text alignment in multi...    2510.11301v1
# 6   What metrics should I use to evaluate text gen...    2510.08662v1
# 7      How can we detect sarcasm using deep learning?    2510.10729v1
# 8   How can I detect or measure bias in deep learn...    2510.10822v1
# 9   How can I reduce hallucinations in large langu...    2510.10822v1
# 10  What techniques improve Transformer training s...    2510.10822v1
# 11  Are deep learning methods effective for crime ...    2509.20913v1
# 12  Should I train separate models for different c...    2509.20913v1
# 13  Which deep learning approaches work well for g...    2510.05736v1
# 14  What frameworks and optimization strategies we...    2510.08662v1
# 15  How do modern architectures perform on complex...    2510.09187v1
# 16  How can I train models stably with limited com...    2509.20913v1
# 17  Why is preprocessing important for Ethic-BERT’...    2510.12850v1
# 18  What are the main strengths of using an LSTM m...    2510.13137v1
# 19  How does model selection affect responsiveness...    2510.08662v1
#
#    correct_paper  is_correct
# 0            NaN       False
# 1            NaN       False
# 2            NaN       False
# 3            NaN       False
# 4            NaN       False
# 5            NaN       False
# 6            NaN       False
# 7            NaN       False
# 8            NaN       False
# 9            NaN       False
# 10           NaN       False
# 11  2509.20913v1        True
# 12   509.20913v1       False
# 13  2510.05736v1        True
# 14  2510.08662v1        True
# 15  2510.09187v1        True
# 16  2510.12850v1       False
# 17  2510.12850v1        True
# 18  2510.13137v1        True
# 19  2510.13137v1       False
