# %%
import os
import re
import string
import glob
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import spacy
import stanza
from stanza.utils.conll import CoNLL
from pathlib import Path

nlp = spacy.load("en_core_web_lg")
stop_words = set(stopwords.words('english'))

# %%
INPUT_DIR = Path("~/TUW_NLP2025/paper_txt").expanduser()
OUTPUT_DIR = Path("~/TUW_NLP2025/code/data").expanduser()
os.makedirs(output_folder, exist_ok=True)

# %%
def prep_text(t):
    # Convert to lowercase
    t = t.lower()

    # Remove email addresses
    t = re.sub(r'\S+@\S+', ' ', t)

    # Remove URLs
    t = re.sub(r'http\S+|www\.\S+', ' ', t)

    # Remove special characters (keep words, numbers, and basic punctuation)
    t = re.sub(r'[^a-z0-9\s.,]', ' ', t)

    # Remove multiple spaces and newlines
    t = re.sub(r'\s+', ' ', t).strip()

    return t

# %%
prep_data = prep_text(data)
print(prep_data)
# Out:
# a multi task deep learning framework for skin lesion classification, abcde feature quantification, and evolution simulation nharsha kotla, arun kumar rajasekaran, hannah ranab department of chemistry, university of cambridge, cambridge, united kingdom harvard ophthalmology ai lab, harvard medical school, boston, ma, usa n abstract n early detection of melanoma has grown to be essential because it significantly improves survival rates, but automated analysis of skin lesions still remains challenging. abcde, which stands for asymmetry, border irregularity, color variation, diameter, and evolving, is a well known classification method for skin lesions, but most deep learning mechanisms treat it as a black box, as most of the human interpretable features are not explained. in this work, we propose a deep learning framework that both classifies skin lesions into categories and also quantifies scores for each abcd feature. it simulates the evolution of these features over time in order to represent the e aspect, opening more windows for future exploration. the a, b, c, and d values are quantified particularly within this work. moreover, this framework also visualizes abcd feature trajectories in latent space as skin lesions evolve from benign nevuses to malignant melanoma. the experiments are conducted using the ham10000 dataset that contains around ten thousand images of skin lesions of varying stages. in summary, the classification worked with an accuracy of around 89 percent, with melanoma auc being 0.96, while the feature evaluation performed well in predicting asymmetry, color variation, and diameter, though border irregularity remains more difficult to model. overall, this work provides a deep learning framework that will allow doctors to link ml diagnoses to clinically relevant criteria, thus improving our understanding of skin cancer progression. keywords melanoma, skin lesion, abcde criteria, deep learning, ham10000 dataset, generative adversarial networks gans , benign nevi, malignant melanoma 1. introduction melanoma, an aggressive form of skin cancer, is one of the leading causes of death due to skin cancer . early diagnosis is important because the 5 year survival rate exceeds in order 90 for early stage melanoma, but drops below 20 for advanced stages . to differentiate between harmful and harmless lesions, dermatologists utilize the abcde method. a stands for asymmetry, as malignant skin lesions often appear to be uneven b stands for border irregularity, as scientists search for jagged or notched edges c stands for color variation d stands for diameter, as larger lesions are more likely to be malignant and e stands for evolving, as skin lesions evolve over time . if a lesion displays two or more of the attributes described above, the lesion is most likely harmful melanoma. the abcde criteria are effective because they are easy to understand and to screen for suspicious lesions . many deep learning techniques are proficient at classifying skin lesion images as either benign, malignant, or one of several other clinically recognized categories found in datasets such as ham10000 . convolutional neural networks are utilized most commonly, as they are trained to classify images. however, these cnn models lack clear interpretability because they only provide point predictions of lesion type without explanation. in the context of melanoma detection, this lack of explanation can hinder clear, interpretable diagnoses. the e feature of abcde has also proven challenging to evaluate via deep learning methods. single static images fail to capture such a change. some mobile applications ask users to input their moles periodically to observe any changes, but this is difficult to enforce. however, using ai to predict and visualize how a lesion changes over time is a promising direction. recent advances in medical imaging have made it possible to create realistic transformations of medical images. for example, jutte et al. utilized a c ...

# %%
token_data = word_tokenize (prep_data)
print (token_data)
# Out:
# ['a', 'multi', 'task', 'deep', 'learning', 'framework', 'for', 'skin', 'lesion', 'classification', ',', 'abcde', 'feature', 'quantification', ',', 'and', 'evolution', 'simulation', 'nharsha', 'kotla', ',', 'arun', 'kumar', 'rajasekaran', ',', 'hannah', 'ranab', 'department', 'of', 'chemistry', ',', 'university', 'of', 'cambridge', ',', 'cambridge', ',', 'united', 'kingdom', 'harvard', 'ophthalmology', 'ai', 'lab', ',', 'harvard', 'medical', 'school', ',', 'boston', ',', 'ma', ',', 'usa', 'n', 'abstract', 'n', 'early', 'detection', 'of', 'melanoma', 'has', 'grown', 'to', 'be', 'essential', 'because', 'it', 'significantly', 'improves', 'survival', 'rates', ',', 'but', 'automated', 'analysis', 'of', 'skin', 'lesions', 'still', 'remains', 'challenging', '.', 'abcde', ',', 'which', 'stands', 'for', 'asymmetry', ',', 'border', 'irregularity', ',', 'color', 'variation', ',', 'diameter', ',', 'and', 'evolving', ',', 'is', 'a', 'well', 'known', 'classification', 'method', 'for', 'skin', 'lesions', ',', 'but', 'most', 'deep', 'learning', 'mechanisms', 'treat', 'it', 'as', 'a', 'black', 'box', ',', 'as', 'most', 'of', 'the', 'human', 'interpretable', 'features', 'are', 'not', 'explained', '.', 'in', 'this', 'work', ',', 'we', 'propose', 'a', 'deep', 'learning', 'framework', 'that', 'both', 'classifies', 'skin', 'lesions', 'into', 'categories', 'and', 'also', 'quantifies', 'scores', 'for', 'each', 'abcd', 'feature', '.', 'it', 'simulates', 'the', 'evolution', 'of', 'these', 'features', 'over', 'time', 'in', 'order', 'to', 'represent', 'the', 'e', 'aspect', ',', 'opening', 'more', 'windows', 'for', 'future', 'exploration', '.', 'the', 'a', ',', 'b', ',', 'c', ',', 'and', 'd', 'values', 'are', 'quantified', 'particularly', 'within', 'this', 'work', '.', 'moreover', ',', 'this', 'framework', 'also', 'visualizes', 'abcd', 'feature', 'trajectories', 'in', 'latent', 'space', 'as', 'skin', 'lesions', 'evolve', 'from', 'benign', 'nevuses', 'to', 'malignant', 'melanoma', '.', 'the', 'experiments', 'are', 'conducted', 'using', 'the', 'ham10000', 'dataset', 'that', 'contains', 'around', 'ten', 'thousand', 'images', 'of', 'skin', 'lesions', 'of', 'varying', 'stages', '.', 'in', 'summary', ',', 'the', 'classification', 'worked', 'with', 'an', 'accuracy', 'of', 'around', '89', 'percent', ',', 'with', 'melanoma', 'auc', 'being', '0.96', ',', 'while', 'the', 'feature', 'evaluation', 'performed', 'well', 'in', 'predicting', 'asymmetry', ',', 'color', 'variation', ',', 'and', 'diameter', ',', 'though', 'border', 'irregularity', 'remains', 'more', 'difficult', 'to', 'model', '.', 'overall', ',', 'this', 'work', 'provides', 'a', 'deep', 'learning', 'framework', 'that', 'will', 'allow', 'doctors', 'to', 'link', 'ml', 'diagnoses', 'to', 'clinically', 'relevant', 'criteria', ',', 'thus', 'improving', 'our', 'understanding', 'of', 'skin', 'cancer', 'progression', '.', 'keywords', 'melanoma', ',', 'skin', 'lesion', ',', 'abcde', 'criteria', ',', 'deep', 'learning', ',', 'ham10000', 'dataset', ',', 'generative', 'adversarial', 'networks', 'gans', ',', 'benign', 'nevi', ',', 'malignant', 'melanoma', '1.', 'introduction', 'melanoma', ',', 'an', 'aggressive', 'form', 'of', 'skin', 'cancer', ',', 'is', 'one', 'of', 'the', 'leading', 'causes', 'of', 'death', 'due', 'to', 'skin', 'cancer', '.', 'early', 'diagnosis', 'is', 'important', 'because', 'the', '5', 'year', 'survival', 'rate', 'exceeds', 'in', 'order', '90', 'for', 'early', 'stage', 'melanoma', ',', 'but', 'drops', 'below', '20', 'for', 'advanced', 'stages', '.', 'to', 'differentiate', 'between', 'harmful', 'and', 'harmless', 'lesions', ',', 'dermatologists', 'utilize', 'the', 'abcde', 'method', '.', 'a', 'stands', 'for', 'asymmetry', ',', 'as', 'malignant', 'skin', 'lesions', 'often', 'appear', 'to', 'be', 'uneven', 'b', 'stands', 'for', 'border', 'irregularity', ',', 'as', 'scientists', 'search', 'for', 'jagged', 'or', 'notched', 'edges', 'c', 'stands', 'for', 'color', 'variation', 'd', 'stands', 'for', 'diame ...

# %%
def lemmatize_texts(texts):
    """
    Lemmatizes a list of text strings using spaCy.
    Returns a list of lemmatized text strings (lowercased, stopwords removed).
    """
    lemmatized_texts = []

    for text in texts:
        doc = nlp(text)

        lemmas = [
            token.lemma_.lower()
            for token in doc 
        ]
        lemmatized_texts.append(" ".join(lemmas))

    return lemmatized_texts

# %%
lemma_data = lemmatize_texts(token_data)
print(lemma_data)
# Out:
# ['a', 'multi', 'task', 'deep', 'learn', 'framework', 'for', 'skin', 'lesion', 'classification', ',', 'abcde', 'feature', 'quantification', ',', 'and', 'evolution', 'simulation', 'nharsha', 'kotla', ',', 'arun', 'kumar', 'rajasekaran', ',', 'hannah', 'ranab', 'department', 'of', 'chemistry', ',', 'university', 'of', 'cambridge', ',', 'cambridge', ',', 'united', 'kingdom', 'harvard', 'ophthalmology', 'ai', 'lab', ',', 'harvard', 'medical', 'school', ',', 'boston', ',', 'ma', ',', 'usa', 'n', 'abstract', 'n', 'early', 'detection', 'of', 'melanoma', 'have', 'grow', 'to', 'be', 'essential', 'because', 'it', 'significantly', 'improve', 'survival', 'rate', ',', 'but', 'automate', 'analysis', 'of', 'skin', 'lesion', 'still', 'remain', 'challenge', '.', 'abcde', ',', 'which', 'stand', 'for', 'asymmetry', ',', 'border', 'irregularity', ',', 'color', 'variation', ',', 'diameter', ',', 'and', 'evolve', ',', 'be', 'a', 'well', 'know', 'classification', 'method', 'for', 'skin', 'lesion', ',', 'but', 'most', 'deep', 'learn', 'mechanism', 'treat', 'it', 'as', 'a', 'black', 'box', ',', 'as', 'most', 'of', 'the', 'human', 'interpretable', 'feature', 'be', 'not', 'explain', '.', 'in', 'this', 'work', ',', 'we', 'propose', 'a', 'deep', 'learn', 'framework', 'that', 'both', 'classify', 'skin', 'lesion', 'into', 'category', 'and', 'also', 'quantify', 'score', 'for', 'each', 'abcd', 'feature', '.', 'it', 'simulate', 'the', 'evolution', 'of', 'these', 'feature', 'over', 'time', 'in', 'order', 'to', 'represent', 'the', 'e', 'aspect', ',', 'open', 'more', 'window', 'for', 'future', 'exploration', '.', 'the', 'a', ',', 'b', ',', 'c', ',', 'and', 'd', 'value', 'be', 'quantify', 'particularly', 'within', 'this', 'work', '.', 'moreover', ',', 'this', 'framework', 'also', 'visualize', 'abcd', 'feature', 'trajectory', 'in', 'latent', 'space', 'as', 'skin', 'lesion', 'evolve', 'from', 'benign', 'nevus', 'to', 'malignant', 'melanoma', '.', 'the', 'experiment', 'be', 'conduct', 'use', 'the', 'ham10000', 'dataset', 'that', 'contain', 'around', 'ten', 'thousand', 'image', 'of', 'skin', 'lesion', 'of', 'vary', 'stage', '.', 'in', 'summary', ',', 'the', 'classification', 'work', 'with', 'an', 'accuracy', 'of', 'around', '89', 'percent', ',', 'with', 'melanoma', 'auc', 'be', '0.96', ',', 'while', 'the', 'feature', 'evaluation', 'perform', 'well', 'in', 'predict', 'asymmetry', ',', 'color', 'variation', ',', 'and', 'diameter', ',', 'though', 'border', 'irregularity', 'remain', 'more', 'difficult', 'to', 'model', '.', 'overall', ',', 'this', 'work', 'provide', 'a', 'deep', 'learn', 'framework', 'that', 'will', 'allow', 'doctor', 'to', 'link', 'ml', 'diagnosis', 'to', 'clinically', 'relevant', 'criterion', ',', 'thus', 'improve', 'our', 'understand', 'of', 'skin', 'cancer', 'progression', '.', 'keyword', 'melanoma', ',', 'skin', 'lesion', ',', 'abcde', 'criterion', ',', 'deep', 'learn', ',', 'ham10000', 'dataset', ',', 'generative', 'adversarial', 'network', 'gan', ',', 'benign', 'nevus', ',', 'malignant', 'melanoma', '1 .', 'introduction', 'melanoma', ',', 'an', 'aggressive', 'form', 'of', 'skin', 'cancer', ',', 'be', 'one', 'of', 'the', 'lead', 'cause', 'of', 'death', 'due', 'to', 'skin', 'cancer', '.', 'early', 'diagnosis', 'be', 'important', 'because', 'the', '5', 'year', 'survival', 'rate', 'exceed', 'in', 'order', '90', 'for', 'early', 'stage', 'melanoma', ',', 'but', 'drop', 'below', '20', 'for', 'advanced', 'stage', '.', 'to', 'differentiate', 'between', 'harmful', 'and', 'harmless', 'lesion', ',', 'dermatologist', 'utilize', 'the', 'abcde', 'method', '.', 'a', 'stand', 'for', 'asymmetry', ',', 'as', 'malignant', 'skin', 'lesion', 'often', 'appear', 'to', 'be', 'uneven', 'b', 'stand', 'for', 'border', 'irregularity', ',', 'as', 'scientist', 'search', 'for', 'jagged', 'or', 'notch', 'edge', 'c', 'stand', 'for', 'color', 'variation', 'd', 'stand', 'for', 'diameter', ',', 'as', 'large', 'lesion', 'be', 'more', 'likely', 'to', 'be', 'malignant', 'and', 'e', 'stand' ...

# %%
def remove_stopwords(texts):
    """
    Removes English stopwords and punctuation from a list of text strings.
    Returns a list of cleaned text strings.
    """
    cleaned_texts = []

    for text in texts:
        # Tokenize text
        words = word_tokenize(text.lower())

        # Filter out stopwords and punctuation
        filtered_words = [
            w for w in words if w not in stop_words and w not in string.punctuation
        ]

        # Join tokens back into a single string
        cleaned_texts.append(" ".join(filtered_words))

    return cleaned_texts

# %%
final_data = remove_stopwords(lemma_data)

print(final_data)
# Out:
# ['', 'multi', 'task', 'deep', 'learn', 'framework', '', 'skin', 'lesion', 'classification', '', 'abcde', 'feature', 'quantification', '', '', 'evolution', 'simulation', 'nharsha', 'kotla', '', 'arun', 'kumar', 'rajasekaran', '', 'hannah', 'ranab', 'department', '', 'chemistry', '', 'university', '', 'cambridge', '', 'cambridge', '', 'united', 'kingdom', 'harvard', 'ophthalmology', 'ai', 'lab', '', 'harvard', 'medical', 'school', '', 'boston', '', '', '', 'usa', 'n', 'abstract', 'n', 'early', 'detection', '', 'melanoma', '', 'grow', '', '', 'essential', '', '', 'significantly', 'improve', 'survival', 'rate', '', '', 'automate', 'analysis', '', 'skin', 'lesion', 'still', 'remain', 'challenge', '', 'abcde', '', '', 'stand', '', 'asymmetry', '', 'border', 'irregularity', '', 'color', 'variation', '', 'diameter', '', '', 'evolve', '', '', '', 'well', 'know', 'classification', 'method', '', 'skin', 'lesion', '', '', '', 'deep', 'learn', 'mechanism', 'treat', '', '', '', 'black', 'box', '', '', '', '', '', 'human', 'interpretable', 'feature', '', '', 'explain', '', '', '', 'work', '', '', 'propose', '', 'deep', 'learn', 'framework', '', '', 'classify', 'skin', 'lesion', '', 'category', '', 'also', 'quantify', 'score', '', '', 'abcd', 'feature', '', '', 'simulate', '', 'evolution', '', '', 'feature', '', 'time', '', 'order', '', 'represent', '', 'e', 'aspect', '', 'open', '', 'window', '', 'future', 'exploration', '', '', '', '', 'b', '', 'c', '', '', '', 'value', '', 'quantify', 'particularly', 'within', '', 'work', '', 'moreover', '', '', 'framework', 'also', 'visualize', 'abcd', 'feature', 'trajectory', '', 'latent', 'space', '', 'skin', 'lesion', 'evolve', '', 'benign', 'nevus', '', 'malignant', 'melanoma', '', '', 'experiment', '', 'conduct', 'use', '', 'ham10000', 'dataset', '', 'contain', 'around', 'ten', 'thousand', 'image', '', 'skin', 'lesion', '', 'vary', 'stage', '', '', 'summary', '', '', 'classification', 'work', '', '', 'accuracy', '', 'around', '89', 'percent', '', '', 'melanoma', 'auc', '', '0.96', '', '', '', 'feature', 'evaluation', 'perform', 'well', '', 'predict', 'asymmetry', '', 'color', 'variation', '', '', 'diameter', '', 'though', 'border', 'irregularity', 'remain', '', 'difficult', '', 'model', '', 'overall', '', '', 'work', 'provide', '', 'deep', 'learn', 'framework', '', '', 'allow', 'doctor', '', 'link', 'ml', 'diagnosis', '', 'clinically', 'relevant', 'criterion', '', 'thus', 'improve', '', 'understand', '', 'skin', 'cancer', 'progression', '', 'keyword', 'melanoma', '', 'skin', 'lesion', '', 'abcde', 'criterion', '', 'deep', 'learn', '', 'ham10000', 'dataset', '', 'generative', 'adversarial', 'network', 'gan', '', 'benign', 'nevus', '', 'malignant', 'melanoma', '1', 'introduction', 'melanoma', '', '', 'aggressive', 'form', '', 'skin', 'cancer', '', '', 'one', '', '', 'lead', 'cause', '', 'death', 'due', '', 'skin', 'cancer', '', 'early', 'diagnosis', '', 'important', '', '', '5', 'year', 'survival', 'rate', 'exceed', '', 'order', '90', '', 'early', 'stage', 'melanoma', '', '', 'drop', '', '20', '', 'advanced', 'stage', '', '', 'differentiate', '', 'harmful', '', 'harmless', 'lesion', '', 'dermatologist', 'utilize', '', 'abcde', 'method', '', '', 'stand', '', 'asymmetry', '', '', 'malignant', 'skin', 'lesion', 'often', 'appear', '', '', 'uneven', 'b', 'stand', '', 'border', 'irregularity', '', '', 'scientist', 'search', '', 'jagged', '', 'notch', 'edge', 'c', 'stand', '', 'color', 'variation', '', 'stand', '', 'diameter', '', '', 'large', 'lesion', '', '', 'likely', '', '', 'malignant', '', 'e', 'stand', '', 'evolve', '', '', 'skin', 'lesion', 'evolve', '', 'time', '', '', '', 'lesion', 'display', 'two', '', '', '', '', 'attribute', 'describe', '', '', '', 'lesion', '', '', 'likely', 'harmful', 'melanoma', '', '', 'abcde', 'criterion', '', 'effective', '', '', '', 'easy', '', 'understand', '', '', 'screen', '', 'suspicious', 'lesion', '', 'many', 'deep', 'learn', 'technique', '', 'proficient', '', 'class ...

# %% [markdown]
# ### The CoNLL format

# %%
txt_files = glob.glob(os.path.join(input_folder, "*.txt"))

print(f"📁 Found {len(txt_files)} text files in {input_folder}")
print(f"📂 Output folder: {output_folder}\n")

for txt_file in txt_files:
    try:
        filename = os.path.basename(txt_file)
        print(f"Processing: {filename}")
        
        with open(txt_file, encoding="utf-8") as f:
            data = f.read()
        
        # Preprocessing pipeline
        prep_data = prep_text(data)
        token_data = word_tokenize(prep_data)
        lemma_data = lemmatize_texts(token_data)
        final_data = remove_stopwords(lemma_data)
        
        # Create CoNLL-U with Stanza
        docs = []
        for text in final_data:
            if text.strip():
                tokens = text.split()
                doc = nlp_stanza([tokens])
                docs.append(doc)
        
        # Save as CoNLL-U
        output_filename = filename.replace('.txt', '.conllu')
        output_path = os.path.join(output_folder, output_filename)
        
        with open(output_path, 'w', encoding='utf-8') as f:
            for doc in docs:
                for sentence in doc.sentences:
                    for token in sentence.tokens:
                        for word in token.words:
                            line = f"{word.id}\t{word.text}\t{word.text}\t{word.upos}\t{word.xpos if word.xpos else '_'}\t_\t0\troot\t_\t_\n"
                            f.write(line)
                    f.write('\n')
                f.write('\n')
        
        print(f"   ✅ Saved: {len(docs)} documents → {output_filename}\n")
        
    except Exception as e:
        print(f"Error processing {filename}: {e}\n")

print("All files processed!")
# Out:
# 📁 Found 20 text files in /Users/tuvshinselenge/Documents/Documents - MacBook Air von Tuvshin/TU/TUW_NLP2025/paper_txt
# 📂 Output folder: /Users/tuvshinselenge/Documents/Documents - MacBook Air von Tuvshin/TU/TUW_NLP2025/code/data
#
# 📄 Processing: 2509.20913v1.txt
#    ✅ Saved: 6274 documents → 2509.20913v1.conllu
#
# 📄 Processing: 2510.10729v1.txt
#    ✅ Saved: 1269 documents → 2510.10729v1.conllu
#
# 📄 Processing: 2510.12758v1.txt
#    ✅ Saved: 6974 documents → 2510.12758v1.conllu
#
# 📄 Processing: 2510.11301v1.txt
#    ✅ Saved: 2189 documents → 2510.11301v1.conllu
#
# 📄 Processing: 2510.08662v1.txt
#    ✅ Saved: 3279 documents → 2510.08662v1.conllu
#
# 📄 Processing: 2510.10822v1.txt
#    ✅ Saved: 3281 documents → 2510.10822v1.conllu
#
# 📄 Processing: 2510.13937v1.txt
#    ✅ Saved: 4393 documents → 2510.13937v1.conllu
#
# 📄 Processing: 2510.12850v1.txt
#    ✅ Saved: 2285 documents → 2510.12850v1.conllu
#
# 📄 Processing: 2510.08116v1.txt
#    ✅ Saved: 3796 documents → 2510.08116v1.conllu
#
# 📄 Processing: 2510.14855v1.txt
#    ✅ Saved: 2395 documents → 2510.14855v1.conllu
#
# 📄 Processing: 2510.13137v1.txt
#    ✅ Saved: 2597 documents → 2510.13137v1.conllu
#
# 📄 Processing: 2509.23158v1.txt
#    ✅ Saved: 3706 documents → 2509.23158v1.conllu
#
# 📄 Processing: 2510.13050v1.txt
#    ✅ Saved: 3755 documents → 2510.13050v1.conllu
#
# 📄 Processing: 2510.07320v1.txt
#    ✅ Saved: 2838 documents → 2510.07320v1.conllu
#
# 📄 Processing: 2510.05163v1.txt
#    ✅ Saved: 2421 documents → 2510.05163v1.conllu
#
# 📄 Processing: 2510.08770v1.txt
#    ✅ Saved: 2016 documents → 2510.08770v1.conllu
#
# 📄 Processing: 2510.05736v1.txt
#    ✅ Saved: 1146 documents → 2510.05736v1.conllu
#
# 📄 Processing: 2510.11073v1.txt
#    ✅ Saved: 8821 documents → 2510.11073v1.conllu
#
# 📄 Processing: 2510.08411v1.txt
#    ✅ Saved: 2012 documents → 2510.08411v1.conllu
#
# 📄 Processing: 2510.09187v1.txt
#    ✅ Saved: 2250 documents → 2510.09187v1.conllu
#
# 🎉 All files processed!
